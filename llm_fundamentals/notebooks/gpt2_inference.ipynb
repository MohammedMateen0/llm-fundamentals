# %%
from transformers import AutoTokenizer,AutoModelForCausalLM

# %%
model_name="gpt2"

# %%
tokenizer=AutoTokenizer.from_pretrained(model_name)
model=AutoModelForCausalLM.from_pretrained(model_name)
# Out:
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]

# %%
prompt="Machine learning is"

# %%
inputs=tokenizer(prompt,return_tensors="pt")

# %%
outputs=model.generate(
    **inputs,

    temperature=0.1,
    max_new_tokens=50,
    do_sample=True
)
print(tokenizer.decode(outputs[0],skip_special_tokens=True))
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Machine learning is a very complex and complex process. It is not easy to understand, but it is very easy to understand.
#
# The first step is to understand the concepts of learning and learning by looking at the data.
#
# The first step is to understand

# %%
outputs=model.generate(
    **inputs,
    temperature=0.5,
    max_new_tokens=50,
    do_sample=True
)
print(tokenizer.decode(outputs[0],skip_special_tokens=True))
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Machine learning is a very different approach to learning than using a learning model.
#
# It's not like you can't learn a new thing by taking a class. You can learn something by taking a class.
#
# In fact, many people who are teaching artificial

# %%
outputs=model.generate(
    **inputs,
    temperature=1.5,
    max_new_tokens=50,
    do_sample=True
)
print(tokenizer.decode(outputs[0],skip_special_tokens=True))
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Machine learning is one that I'm already working with a friend over and over -- she can play music on top of my TV remote right now or we could have games on the remote for a while.
#
# I can easily be using virtual reality experiences with real players

# %%
outputs=model.generate(
    **inputs,
    top_k=0,
    max_new_tokens=50,
    do_sample=True
)
print(tokenizer.decode(outputs[0],skip_special_tokens=True))
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Machine learning is time consuming, cumbersome and more expensive than neuroscience, which makes the privilege of programming more important. Furthermore, while there is growing interest in AI research behind smart phones, future-proof platforms still need considerable work done and expect to struggle, its kernel architecture

# %%
outputs=model.generate(
    **inputs,
    max_new_tokens=50,
    top_k=10,
    do_sample=True
)
print(tokenizer.decode(outputs[0],skip_special_tokens=True))
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Machine learning is an important aspect of the business of AI in this area. This is where the company, which is currently based in India, works. They are working on a product called 'AI-Learning Machine Learning'.
#
# The company says they've already launched

# %%
outputs=model.generate(
    **inputs,
    max_new_tokens=50,
    top_k=50,
    do_sample=True
)
print(tokenizer.decode(outputs[0],skip_special_tokens=True))
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Machine learning is a science project that I will be using in the course of writing this post. I'll begin by telling you what Python learning is and how it works, using Python as an example.
#
# Let's break it down into four basic steps in Python

# %%
outputs=model.generate(
    **inputs,
    max_new_tokens=50,
    top_p=0.1,
    do_sample=True
)
print(tokenizer.decode(outputs[0],skip_special_tokens=True))
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Machine learning is a very powerful tool for learning about the world around us. It's a tool that can help us understand the world around us, and it's a tool that can help us understand the world around us.
#
# The world is changing. We're

# %%
outputs=model.generate(
    **inputs,
    max_new_tokens=50,
    top_p=0.5,
    do_sample=True
)
print(tokenizer.decode(outputs[0],skip_special_tokens=True))
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Machine learning is a very powerful tool that has tremendous potential for making our lives better.
#
# It is also a great way to understand how your brain works. In this article, we will explore how your brain learns to recognize the emotions of other people.

# %%
outputs=model.generate(
    **inputs,
    max_new_tokens=50,
    top_p=0.95,
    do_sample=True
)
print(tokenizer.decode(outputs[0],skip_special_tokens=True))
# Out:
# [transformers] Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Machine learning is not only highly desirable but it has potential as a revolutionary technology in a number of industries: healthcare, healthcare, finance, transportation, medicine, and more.
#
# The next time you're in the field, consider whether or not your next career is
